# %%
import sys, os
sys.path.append('../../')
from dataset import load_img
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import sys, os
#       2 sys.path.append('../../')
# ----> 3 from dataset import load_img
#
# File ~/Project/asbestos/notebooks/dataloader/../../dataset/__init__.py:1, in <module>
# ----> 1 from .dataset import AsbestosDataSet, is_image, load_img, get_paths, ImageDirDataset
#       2 from .io import Image
#
# File ~/Project/asbestos/notebooks/dataloader/../../dataset/dataset.py:21, in <module>
#      19 from abc import ABC, abstractmethod
#      20 import cv2
# ---> 21 from f_logging import debug_load_img
#      23 PathLike = Union[Path, str]
#      25 IMG_FORMATS = 'bmp', 'dng', 'jpeg', 'jpg', 'mpo', 'png', 'tif', 'tiff', 'webp'
#
# ModuleNotFoundError: No module named 'f_logging'

# %%
# %cd ../../YOLOv6/
# %cd ../YOLOv6/
# Out:
# /home/kirilman/Project/asbestos/YOLOv6

# %%
# !python tools/train.py --img 512 --batch 2 --conf configs/yolov6l.py --data  /home/kirilman/Project/dataset/detection_set2/yolov6.yaml \
--name 'yolov6l' \
--epochs 400
# Out:
# Using 1 GPU for training...
# training args are: Namespace(data_path='/home/kirilman/Project/dataset/detection_set2/yolov6.yaml', conf_file='configs/yolov6l.py', img_size=512, batch_size=2, epochs=400, workers=8, device='0', eval_interval=20, eval_final_only=False, heavy_eval_range=50, check_images=False, check_labels=False, output_dir='./runs/train', name='yolov6l', dist_url='env://', gpu_count=0, local_rank=-1, resume=False, write_trainbatch_tb=False, stop_aug_last_n_epoch=15, save_ckpt_on_last_n_epoch=-1, distill=False, distill_feat=False, quant=False, calib=False, teacher_model_path=None, temperature=20, rank=-1, world_size=1, save_dir='runs/train/yolov6l')
#
# Train: Final numbers of valid images: 308/ labels: 308.
# 0.0s for dataset initialization.
# Convert to COCO format
# 100%|████████████████████████████████████████| 18/18 [00:00<00:00, 20197.29it/s]
# ...

# %%
# !python tools/eval.py --img 512 --weights ./runs/train/yolov6l/weights/best_ckpt.pt \
--data /home/kirilman/Project/dataset/detection_set2/yolov6_for_text.yaml --do_coco_metric True \
# --task val
# Out:
# Namespace(data='/home/kirilman/Project/dataset/detection_set2/yolov6_for_text.yaml', weights='./runs/train/yolov6l/weights/best_ckpt.pt', batch_size=32, img_size=512, conf_thres=0.03, iou_thres=0.65, task='val', device='0', half=False, save_dir='runs/val/', name='exp', test_load_size=640, letterbox_return_int=False, scale_exact=False, force_no_pad=False, not_infer_on_rect=False, reproduce_640_eval=False, eval_config_file='./configs/experiment/eval_640_repro.py', do_coco_metric=True, do_pr_metric=False, plot_curve=True, plot_confusion_matrix=False, verbose=False, config_file='')
# Loading checkpoint from ./runs/train/yolov6l/weights/best_ckpt.pt
#
# Fusing model...
# /home/kirilman/miniconda3/lib/python3.9/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 import sys, os
#       2 sys.path.append('../../')
# ----> 3 from dataset import load_img
#
# ImportError: cannot import name 'load_img' from 'dataset' (unknown location)

# %%
sys.path
# Out:
# ['/home/kirilman/Project/asbestos/notebooks/dataloader',
#  '/home/kirilman/miniconda3/lib/python39.zip',
#  '/home/kirilman/miniconda3/lib/python3.9',
#  '/home/kirilman/miniconda3/lib/python3.9/lib-dynload',
#  '',
#  '/home/kirilman/miniconda3/lib/python3.9/site-packages',
#  '../../',
#  '../',
#  '../../../',
#  '../../']
